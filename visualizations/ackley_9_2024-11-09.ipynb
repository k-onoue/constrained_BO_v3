# %% [markdown]
# # Parafac Sampler の詳細な検証
#
# - randam 周り
# -

# %%
# dim 5 ~ 7 ではこうなっている

""" 
2024-11-03 09:37:19,145 - INFO - Experiment settings: {'name': 'bo_parafac_dim5_rank2_mask0.1_tradeoff3.0_seed4', 'seed': 4, 'dimensions': 5, 'iter_bo': 500, 'storage': 'sqlite:////app/results/dbs/2024-11-03_09-37-19_bo_parafac_dim5_rank2_mask0.1_tradeoff3.0_seed4.db', 'unique_sampling': False, 'cp_settings': {'rank': 2, 'als_iterations': 100, 'mask_ratio': 0.1, 'random_dist_type': 'uniform'}, 'acqf_settings': {'trade_off_param': 3.0, 'maximize': False}}
2024-11-03 09:37:20,016 - INFO - Created new study 'bo_parafac_dim5_rank2_mask0.1_tradeoff3.0_seed4' in sqlite:////app/results/dbs/2024-11-03_09-37-19_bo_parafac_dim5_rank2_mask0.1_tradeoff3.0_seed4.db
2024-11-03 09:37:20,054 - INFO - Using sample_independent for sampling.
2024-11-03 09:37:20,064 - INFO - Using sample_independent for sampling.
2024-11-03 09:37:20,072 - INFO - Using sample_independent for sampling.
2024-11-03 09:37:20,079 - INFO - Using sample_independent for sampling.
2024-11-03 09:37:20,086 - INFO - Using sample_independent for sampling.
2024-11-03 09:37:21,065 - INFO - Candidate Mean Stats: {'Max': np.float64(64.0007913130576), 'Min': np.float64(64.0007913130576), 'Mean': np.float64(64.0007913130576), 'Std': np.float64(0.0)}
2024-11-03 09:37:21,066 - INFO - Candidate Std Stats: {'Max': np.float64(0.005041275760494847), 'Min': np.float64(0.005041275760494847), 'Mean': np.float64(0.005041275760494847), 'Std': np.float64(0.0)}
2024-11-03 09:37:23,236 - INFO - Candidate Mean Stats: {'Max': np.float64(17.0), 'Min': np.float64(17.0), 'Mean': np.float64(17.0), 'Std': np.float64(0.0)}
2024-11-03 09:37:23,236 - INFO - Candidate Std Stats: {'Max': np.float64(0.0), 'Min': np.float64(0.0), 'Mean': np.float64(0.0), 'Std': np.float64(0.0)}
2024-11-03 09:37:24,235 - INFO - Candidate Mean Stats: {'Max': np.float64(17.0), 'Min': np.float64(17.0), 'Mean': np.float64(17.0), 'Std': np.float64(0.0)}
2024-11-03 09:37:24,236 - INFO - Candidate Std Stats: {'Max': np.float64(0.0), 'Min': np.float64(0.0), 'Mean': np.float64(0.0), 'Std': np.float64(0.0)}
2024-11-03 09:37:25,514 - INFO - Candidate Mean Stats: {'Max': np.float64(17.0), 'Min': np.float64(17.0), 'Mean': np.float64(17.0), 'Std': np.float64(0.0)}
2024-11-03 09:37:25,514 - INFO - Candidate Std Stats: {'Max': np.float64(0.0), 'Min': np.float64(0.0), 'Mean': 
~
2024-11-03 09:51:19,216 - INFO - Candidate Std Stats: {'Max': np.float64(0.0), 'Min': np.float64(0.0), 'Mean': np.float64(0.0), 'Std': np.float64(0.0)}
2024-11-03 09:51:20,216 - INFO - Candidate Mean Stats: {'Max': np.float64(17.0), 'Min': np.float64(17.0), 'Mean': np.float64(17.0), 'Std': np.float64(0.0)}
2024-11-03 09:51:20,216 - INFO - Candidate Std Stats: {'Max': np.float64(0.0), 'Min': np.float64(0.0), 'Mean': np.float64(0.0), 'Std': np.float64(0.0)}
2024-11-03 09:51:20,256 - INFO - Best value: 17.0
2024-11-03 09:51:20,260 - INFO - Best params: {'x_0': 2, 'x_1': 2, 'x_2': -2, 'x_3': 2, 'x_4': -1}
"""

# %%
# trade_off_param 3.0 -> 100
# 分散を重視すれば，正常に動作しているように見える

"""
INFO - Candidate Std Stats: {'Max': np.float64(0.3108429581622203), 'Min': np.float64(0.3108429581622203), 'Mean': np.float64(0.3108429581622203), 'Std': np.float64(0.0)}
[I 2024-11-09 11:12:01,326] Trial 295 finished with value: 5.688430545227675 and parameters: {'x_0': -1, 'x_1': -1, 'x_2': 2, 'x_3': 2, 'x_4': -2}. Best is trial 237 with value: 3.2759661863843736.
2024-11-09 11:12:01,810 - INFO - Candidate Mean Stats: {'Max': np.float64(7.615648876776906), 'Min': np.float64(7.615648876776906), 'Mean': np.float64(7.615648876776906), 'Std': np.float64(0.0)}
2024-11-09 11:12:01,810 - INFO - Candidate Std Stats: {'Max': np.float64(0.23763988114523055), 'Min': np.float64(0.23763988114523055), 'Mean': np.float64(0.23763988114523055), 'Std': np.float64(0.0)}
[I 2024-11-09 11:12:01,822] Trial 296 finished with value: 10.275757266411311 and parameters: {'x_0': 5, 'x_1': 2, 'x_2': 2, 'x_3': -4, 'x_4': -4}. Best is trial 237 with value: 3.2759661863843736.
2024-11-09 11:12:02,497 - INFO - Candidate Mean Stats: {'Max': np.float64(7.623404630217776), 'Min': np.float64(7.623404630217776), 'Mean': np.float64(7.623404630217776), 'Std': np.float64(0.0)}
2024-11-09 11:12:02,498 - INFO - Candidate Std Stats: {'Max': np.float64(0.23360423837965508), 'Min': np.float64(0.23360423837965508), 'Mean': np.float64(0.23360423837965508), 'Std': np.float64(0.0)}
[I 2024-11-09 11:12:02,510] Trial 297 finished with value: 8.798169485887737 and parameters: {'x_0': 3, 'x_1': 5, 'x_2': -2, 'x_3': 0, 'x_4': -2}. Best is trial 237 with value: 3.2759661863843736.
2024-11-09 11:12:03,186 - INFO - Candidate Mean Stats: {'Max': np.float64(7.622136140458193), 'Min': np.float64(7.622136140458193), 'Mean': np.float64(7.622136140458193), 'Std': np.float64(0.0)}
2024-11-09 11:12:03,186 - INFO - Candidate Std Stats: {'Max': np.float64(0.26283407095970446), 'Min': np.float64(0.26283407095970446), 'Mean': np.float64(0.26283407095970446), 'Std': np.float64(0.0)}
[I 2024-11-09 11:12:03,197] Trial 298 finished with value: 7.211853616762058 and parameters: {'x_0': -2, 'x_1': 0, 'x_2': 1, 'x_3': 4, 'x_4': -2}. Best is trial 237 with value: 3.2759661863843736.
2024-11-09 11:12:03,785 - INFO - Candidate Mean Stats: {'Max': np.float64(7.611532792824482), 'Min': np.float64(7.611532792824482), 'Mean': np.float64(7.611532792824482), 'Std': np.float64(0.0)}
2024-11-09 11:12:03,786 - INFO - Candidate Std Stats: {'Max': np.float64(0.2650681680720595), 'Min': np.float64(0.2650681680720595), 'Mean': np.float64(0.2650681680720595), 'Std': np.float64(0.0)}
[I 2024-11-09 11:12:03,797] Trial 299 finished with value: 10.110638344748036 and parameters: {'x_0': 4, 'x_1': -4, 'x_2': -5, 'x_3': 2, 'x_4': 1}. Best is trial 237 with value: 3.2759661863843736.
2024-11-09 11:12:03,799 - INFO - Best value: 3.2759661863843736
2024-11-09 11:12:03,800 - INFO - Best params: {'x_0': 1, 'x_1': -1, 'x_2': -1, 'x_3': -1, 'x_4': 0}
(bo-env_v2) keisukeonoue@ws23is058 [11:12:03] [~/ws/constrained_BO_v2] [main]
-> % python3 experiments/2024-11-09/ackley/bo_parafac.py --dimensions 5 --acq_trade_off_param 100
"""

# %%
# 観測点が増えていっていない

""" 
(bo-env_v2) keisukeonoue@ws23is058 [11:17:40] [~/ws/constrained_BO_v2] [main *]
-> % python3 experiments/2024-11-09/ackley/bo_parafac.py --dimensions 5 
2024-11-09 11:18:51,102 - INFO - Experiment settings: {'name': 'ackley_bo_parafac_dim5_rank2_mask0.1_tradeoff3.0_seed0_includeobsFalse', 'seed': 0, 'dimensions': 5, 'iter_bo': 300, 'storage': 'sqlite:////Users/keisukeonoue/ws/constrained_BO_v2/results/dbs/2024-11-09_11-18-51_ackley_bo_parafac_dim5_rank2_mask0.1_tradeoff3.0_seed0_includeobsFalse.db', 'unique_sampling': False, 'cp_settings': {'rank': 2, 'als_iterations': 100, 'mask_ratio': 0.1, 'include_observed_points': False, 'random_dist_type': 'uniform'}, 'acqf_settings': {'trade_off_param': 3.0, 'maximize': False}}
[I 2024-11-09 11:18:51,344] A new study created in RDB with name: ackley_bo_parafac_dim5_rank2_mask0.1_tradeoff3.0_seed0_includeobsFalse
2024-11-09 11:18:51,345 - INFO - Created new study 'ackley_bo_parafac_dim5_rank2_mask0.1_tradeoff3.0_seed0_includeobsFalse' in sqlite:////Users/keisukeonoue/ws/constrained_BO_v2/results/dbs/2024-11-09_11-18-51_ackley_bo_parafac_dim5_rank2_mask0.1_tradeoff3.0_seed0_includeobsFalse.db
2024-11-09 11:18:51,357 - INFO - Using sample_independent for sampling.
2024-11-09 11:18:51,360 - INFO - Using sample_independent for sampling.
2024-11-09 11:18:51,361 - INFO - Using sample_independent for sampling.
2024-11-09 11:18:51,363 - INFO - Using sample_independent for sampling.
2024-11-09 11:18:51,364 - INFO - Using sample_independent for sampling.
[I 2024-11-09 11:18:51,372] Trial 0 finished with value: 10.38223350306957 and parameters: {'x_0': 3, 'x_1': 4, 'x_2': 4, 'x_3': 5, 'x_4': -1}. Best is trial 0 with value: 10.38223350306957.
2024-11-09 11:18:51,679 - INFO - Candidate Mean Stats: {'Max': np.float64(10.379106619344984), 'Min': np.float64(10.379106619344984), 'Mean': np.float64(10.379106619344984), 'Std': np.float64(0.0)}
2024-11-09 11:18:51,680 - INFO - Candidate Std Stats: {'Max': np.float64(0.004585683407732279), 'Min': np.float64(0.004585683407732279), 'Mean': np.float64(0.004585683407732279), 'Std': np.float64(0.0)}



Top indices: [(np.int64(10), np.int64(2), np.int64(10), np.int64(10), np.int64(6))]
Observed indices: [(8, 9, 9, 10, 4)]



[I 2024-11-09 11:18:51,691] Trial 1 finished with value: 11.231978796979323 and parameters: {'x_0': 5, 'x_1': -3, 'x_2': 5, 'x_3': 5, 'x_4': 1}. Best is trial 0 with value: 10.38223350306957.
2024-11-09 11:18:52,033 - INFO - Candidate Mean Stats: {'Max': np.float64(10.38223350306957), 'Min': np.float64(10.38223350306957), 'Mean': np.float64(10.38223350306957), 'Std': np.float64(0.0)}
2024-11-09 11:18:52,033 - INFO - Candidate Std Stats: {'Max': np.float64(0.0), 'Min': np.float64(0.0), 'Mean': np.float64(0.0), 'Std': np.float64(0.0)}



Top indices: [(np.int64(8), np.int64(9), np.int64(9), np.int64(10), np.int64(4))]
Observed indices: [(8, 9, 9, 10, 4), (10, 2, 10, 10, 6)]



[I 2024-11-09 11:18:52,044] Trial 2 finished with value: 10.38223350306957 and parameters: {'x_0': 3, 'x_1': 4, 'x_2': 4, 'x_3': 5, 'x_4': -1}. Best is trial 0 with value: 10.38223350306957.
2024-11-09 11:18:52,391 - INFO - Candidate Mean Stats: {'Max': np.float64(10.38223350306957), 'Min': np.float64(10.38223350306957), 'Mean': np.float64(10.38223350306957), 'Std': np.float64(0.0)}
2024-11-09 11:18:52,391 - INFO - Candidate Std Stats: {'Max': np.float64(0.0), 'Min': np.float64(0.0), 'Mean': np.float64(0.0), 'Std': np.float64(0.0)}

"""


# これは5次元だから
""" 
2024-11-09 11:18:51,357 - INFO - Using sample_independent for sampling.
2024-11-09 11:18:51,360 - INFO - Using sample_independent for sampling.
2024-11-09 11:18:51,361 - INFO - Using sample_independent for sampling.
2024-11-09 11:18:51,363 - INFO - Using sample_independent for sampling.
2024-11-09 11:18:51,364 - INFO - Using sample_independent for sampling.
"""

# %%
# やはりよくわからないものを計測していた

""" 
(bo-env_v2) keisukeonoue@ws23is058 [11:20:58] [~/ws/constrained_BO_v2] [main *]
-> % python3 experiments/2024-11-09/ackley/bo_parafac.py --dimensions 5 --acq_trade_off_param 100
2024-11-09 11:28:50,490 - INFO - Experiment settings: {'name': 'ackley_bo_parafac_dim5_rank2_mask0.1_tradeoff100.0_seed0_includeobsFalse', 'seed': 0, 'dimensions': 5, 'iter_bo': 300, 'storage': 'sqlite:////Users/keisukeonoue/ws/constrained_BO_v2/results/dbs/2024-11-09_11-28-50_ackley_bo_parafac_dim5_rank2_mask0.1_tradeoff100.0_seed0_includeobsFalse.db', 'unique_sampling': False, 'cp_settings': {'rank': 2, 'als_iterations': 100, 'mask_ratio': 0.1, 'include_observed_points': False, 'random_dist_type': 'uniform'}, 'acqf_settings': {'trade_off_param': 100.0, 'maximize': False}}
[I 2024-11-09 11:28:50,738] A new study created in RDB with name: ackley_bo_parafac_dim5_rank2_mask0.1_tradeoff100.0_seed0_includeobsFalse
2024-11-09 11:28:50,739 - INFO - Created new study 'ackley_bo_parafac_dim5_rank2_mask0.1_tradeoff100.0_seed0_includeobsFalse' in sqlite:////Users/keisukeonoue/ws/constrained_BO_v2/results/dbs/2024-11-09_11-28-50_ackley_bo_parafac_dim5_rank2_mask0.1_tradeoff100.0_seed0_includeobsFalse.db
2024-11-09 11:28:50,751 - INFO - Using sample_independent for sampling.
2024-11-09 11:28:50,753 - INFO - Using sample_independent for sampling.
2024-11-09 11:28:50,755 - INFO - Using sample_independent for sampling.
2024-11-09 11:28:50,756 - INFO - Using sample_independent for sampling.
2024-11-09 11:28:50,757 - INFO - Using sample_independent for sampling.
[I 2024-11-09 11:28:50,765] Trial 0 finished with value: 8.2178931574933 and parameters: {'x_0': -4, 'x_1': -1, 'x_2': -1, 'x_3': 1, 'x_4': -4}. Best is trial 0 with value: 8.2178931574933.
2024-11-09 11:28:51,076 - INFO - Candidate Mean Stats: {'Max': np.float64(8.220027971192009), 'Min': np.float64(8.220027971192009), 'Mean': np.float64(8.220027971192009), 'Std': np.float64(0.0)}
2024-11-09 11:28:51,076 - INFO - Candidate Std Stats: {'Max': np.float64(0.005614718570755222), 'Min': np.float64(0.005614718570755222), 'Mean': np.float64(0.005614718570755222), 'Std': np.float64(0.0)}



Top indices: [(np.int64(7), np.int64(8), np.int64(1), np.int64(0), np.int64(6))]
Observed indices: [(1, 4, 4, 6, 1)]



[I 2024-11-09 11:28:51,088] Trial 1 finished with value: 9.697286414061548 and parameters: {'x_0': 2, 'x_1': 3, 'x_2': -4, 'x_3': -5, 'x_4': 1}. Best is trial 0 with value: 8.2178931574933.
2024-11-09 11:28:51,445 - INFO - Candidate Mean Stats: {'Max': np.float64(8.954187468651352), 'Min': np.float64(8.954187468651352), 'Mean': np.float64(8.954187468651352), 'Std': np.float64(0.0)}
2024-11-09 11:28:51,445 - INFO - Candidate Std Stats: {'Max': np.float64(0.03868397852062205), 'Min': np.float64(0.03868397852062205), 'Mean': np.float64(0.03868397852062205), 'Std': np.float64(0.0)}



Top indices: [(np.int64(10), np.int64(2), np.int64(9), np.int64(8), np.int64(1))]
Observed indices: [(1, 4, 4, 6, 1), (7, 8, 1, 0, 6)]



[I 2024-11-09 11:28:51,456] Trial 2 finished with value: 10.782207310357974 and parameters: {'x_0': 5, 'x_1': -3, 'x_2': 4, 'x_3': 3, 'x_4': -4}. Best is trial 0 with value: 8.2178931574933.
2024-11-09 11:28:51,830 - INFO - Candidate Mean Stats: {'Max': np.float64(9.505324835608969), 'Min': np.float64(9.505324835608969), 'Mean': np.float64(9.505324835608969), 'Std': np.float64(0.0)}
2024-11-09 11:28:51,830 - INFO - Candidate Std Stats: {'Max': np.float64(0.07265881652338115), 'Min': np.float64(0.07265881652338115), 'Mean': np.float64(0.07265881652338115), 'Std': np.float64(0.0)}



Top indices: [(np.int64(0), np.int64(10), np.int64(7), np.int64(8), np.int64(0))]
Observed indices: [(1, 4, 4, 6, 1), (7, 8, 1, 0, 6), (10, 2, 9, 8, 1)]



[I 2024-11-09 11:28:51,841] Trial 3 finished with value: 11.357557885506115 and parameters: {'x_0': -5, 'x_1': 5, 'x_2': 2, 'x_3': 3, 'x_4': -5}. Best is trial 0 with value: 8.2178931574933.
2024-11-09 11:28:52,170 - INFO - Candidate Mean Stats: {'Max': np.float64(9.803168029838055), 'Min': np.float64(9.803168029838055), 'Mean': np.float64(9.803168029838055), 'Std': np.float64(0.0)}
2024-11-09 11:28:52,170 - INFO - Candidate Std Stats: {'Max': np.float64(0.07501300622637126), 'Min': np.float64(0.07501300622637126), 'Mean': np.float64(0.07501300622637126), 'Std': np.float64(0.0)}



Top indices: [(np.int64(3), np.int64(6), np.int64(7), np.int64(2), np.int64(3))]
Observed indices: [(1, 4, 4, 6, 1), (7, 8, 1, 0, 6), (10, 2, 9, 8, 1), (0, 10, 7, 8, 0)]


"""

# %%
""" 
(bo-env_v2) keisukeonoue@ws23is058 [11:50:52] [~/ws/constrained_BO_v2] [main *]
-> % python3 experiments/2024-11-09/ackley/bo_parafac.py --dimensions 5 --acq_trade_off_param 3 --cp_mask_ratio 0.1
2024-11-09 11:52:21,998 - INFO - Experiment settings: {'name': 'ackley_bo_parafac_dim5_rank2_mask0.1_tradeoff3.0_seed0_includeobsFalse', 'seed': 0, 'dimensions': 5, 'iter_bo': 300, 'storage': 'sqlite:////Users/keisukeonoue/ws/constrained_BO_v2/results/dbs/2024-11-09_11-52-21_ackley_bo_parafac_dim5_rank2_mask0.1_tradeoff3.0_seed0_includeobsFalse.db', 'unique_sampling': False, 'cp_settings': {'rank': 2, 'als_iterations': 100, 'mask_ratio': 0.1, 'include_observed_points': False, 'random_dist_type': 'uniform'}, 'acqf_settings': {'trade_off_param': 3.0, 'maximize': False}}
[I 2024-11-09 11:52:22,254] A new study created in RDB with name: ackley_bo_parafac_dim5_rank2_mask0.1_tradeoff3.0_seed0_includeobsFalse
2024-11-09 11:52:22,255 - INFO - Created new study 'ackley_bo_parafac_dim5_rank2_mask0.1_tradeoff3.0_seed0_includeobsFalse' in sqlite:////Users/keisukeonoue/ws/constrained_BO_v2/results/dbs/2024-11-09_11-52-21_ackley_bo_parafac_dim5_rank2_mask0.1_tradeoff3.0_seed0_includeobsFalse.db
2024-11-09 11:52:22,268 - INFO - Using sample_independent for sampling.
2024-11-09 11:52:22,270 - INFO - Using sample_independent for sampling.
2024-11-09 11:52:22,271 - INFO - Using sample_independent for sampling.
2024-11-09 11:52:22,273 - INFO - Using sample_independent for sampling.
2024-11-09 11:52:22,274 - INFO - Using sample_independent for sampling.
[I 2024-11-09 11:52:22,282] Trial 0 finished with value: 10.536892701528078 and parameters: {'x_0': 0, 'x_1': 5, 'x_2': -4, 'x_3': -2, 'x_4': 5}. Best is trial 0 with value: 10.536892701528078.
2024-11-09 11:52:22,559 - INFO - Candidate Mean Stats: {'Max': np.float64(10.53524699501249), 'Min': np.float64(10.53524699501249), 'Mean': np.float64(10.53524699501249), 'Std': np.float64(0.0)}
2024-11-09 11:52:22,559 - INFO - Candidate Std Stats: {'Max': np.float64(0.0061522224083278634), 'Min': np.float64(0.0061522224083278634), 'Mean': np.float64(0.0061522224083278634), 'Std': np.float64(0.0)}
2024-11-09 11:52:22,559 - INFO - Observed Indices: [(5, 10, 1, 3, 10)]


Debug - Bottom 5 UCB Values:
Index: (np.int64(2), np.int64(3), np.int64(9), np.int64(9), np.int64(6)), Mean: 10.538919528648917, Std: 0.0003655390875698132
Index: (np.int64(1), np.int64(8), np.int64(5), np.int64(1), np.int64(1)), Mean: 10.539611974043172, Std: 0.0005690200955044949
Index: (np.int64(4), np.int64(9), np.int64(10), np.int64(6), np.int64(7)), Mean: 10.538416016587442, Std: 0.0001373722984323734
Index: (np.int64(1), np.int64(8), np.int64(5), np.int64(6), np.int64(1)), Mean: 10.539357319083646, Std: 0.00040896214708574725
Index: (np.int64(1), np.int64(8), np.int64(5), np.int64(8), np.int64(1)), Mean: 10.539471234877947, Std: 0.0003223281857601988
[I 2024-11-09 11:52:22,571] Trial 1 finished with value: 11.398545222182436 and parameters: {'x_0': -4, 'x_1': 4, 'x_2': -4, 'x_3': -5, 'x_4': 4}. Best is trial 0 with value: 10.536892701528078.
2024-11-09 11:52:22,895 - INFO - Candidate Mean Stats: {'Max': np.float64(10.536892701528078), 'Min': np.float64(10.536892701528078), 'Mean': np.float64(10.536892701528078), 'Std': np.float64(0.0)}
2024-11-09 11:52:22,895 - INFO - Candidate Std Stats: {'Max': np.float64(0.0), 'Min': np.float64(0.0), 'Mean': np.float64(0.0), 'Std': np.float64(0.0)}
2024-11-09 11:52:22,895 - INFO - Observed Indices: [(5, 10, 1, 3, 10), (1, 9, 1, 0, 9)]


Debug - Bottom 5 UCB Values:
Index: (np.int64(10), np.int64(3), np.int64(10), np.int64(8), np.int64(2)), Mean: 10.976667679632364, Std: 0.001469313330822626
Index: (np.int64(2), np.int64(0), np.int64(9), np.int64(8), np.int64(2)), Mean: 10.977931244251184, Std: 0.0015675105673304383
Index: (np.int64(6), np.int64(2), np.int64(9), np.int64(9), np.int64(9)), Mean: 10.97726103965066, Std: 0.001094766443308302
Index: (np.int64(4), np.int64(2), np.int64(9), np.int64(0), np.int64(3)), Mean: 10.976351078875364, Std: 0.0007467023629448095
Index: (np.int64(1), np.int64(9), np.int64(1), np.int64(0), np.int64(9)), Mean: 11.398545222182436, Std: 0.0
[I 2024-11-09 11:52:22,906] Trial 2 finished with value: 10.536892701528078 and parameters: {'x_0': 0, 'x_1': 5, 'x_2': -4, 'x_3': -2, 'x_4': 5}. Best is trial 0 with value: 10.536892701528078.
2024-11-09 11:52:23,281 - INFO - Candidate Mean Stats: {'Max': np.float64(10.536892701528078), 'Min': np.float64(10.536892701528078), 'Mean': np.float64(10.536892701528078), 'Std': np.float64(0.0)}
2024-11-09 11:52:23,281 - INFO - Candidate Std Stats: {'Max': np.float64(0.0), 'Min': np.float64(0.0), 'Mean': np.float64(0.0), 'Std': np.float64(0.0)}
2024-11-09 11:52:23,281 - INFO - Observed Indices: [(5, 10, 1, 3, 10), (1, 9, 1, 0, 9)]


Debug - Bottom 5 UCB Values:
Index: (np.int64(0), np.int64(4), np.int64(3), np.int64(10), np.int64(0)), Mean: 10.974086174898051, Std: 0.000848298510234552
Index: (np.int64(4), np.int64(3), np.int64(0), np.int64(10), np.int64(1)), Mean: 10.972831836704907, Std: 0.00039722872532414576
Index: (np.int64(4), np.int64(6), np.int64(0), np.int64(10), np.int64(0)), Mean: 10.97884358033718, Std: 0.0019394636645467427
Index: (np.int64(0), np.int64(9), np.int64(0), np.int64(10), np.int64(0)), Mean: 10.978175518250657, Std: 0.0007054971450517414
Index: (np.int64(1), np.int64(9), np.int64(1), np.int64(0), np.int64(9)), Mean: 11.398545222182436, Std: 0.0
[I 2024-11-09 11:52:23,292] Trial 3 finished with value: 10.536892701528078 and parameters: {'x_0': 0, 'x_1': 5, 'x_2': -4, 'x_3': -2, 'x_4': 5}. Best is trial 0 with value: 10.536892701528078.
2024-11-09 11:52:23,596 - INFO - Candidate Mean Stats: {'Max': np.float64(10.536892701528078), 'Min': np.float64(10.536892701528078), 'Mean': np.float64(1
"""

# %%
11 ** 5
# Out:
# 161051

# %%
# unique_sampling にすると明らかに性能が上がる（ノイズなしを仮定できるなら．あと本質はトレードオフパラメータの大きさ）

""" 
(bo-env_v2) keisukeonoue@ws23is058 [11:58:31] [~/ws/constrained_BO_v2] [main *]
-> % python3 experiments/2024-11-09/ackley/bo_parafac.py --dimensions 5 --acq_trade_off_param 3 --cp_mask_ratio 0.1 --uni
2024-11-09 12:14:38,528 - INFO - Experiment settings: {'name': 'ackley_bo_parafac_dim5_rank2_mask0.1_tradeoff3.0_seed0_includeobsFalse', 'seed': 0, 'dimensions': 5, 'iter_bo': 300, 'storage': 'sqlite:////Users/keisukeonoue/ws/constrained_BO_v2/results/dbs/2024-11-09_12-14-38_ackley_bo_parafac_dim5_rank2_mask0.1_tradeoff3.0_seed0_includeobsFalse.db', 'unique_sampling': True, 'cp_settings': {'rank': 2, 'als_iterations': 100, 'mask_ratio': 0.1, 'include_observed_points': False, 'random_dist_type': 'uniform'}, 'acqf_settings': {'trade_off_param': 3.0, 'maximize': False}}
[I 2024-11-09 12:14:38,775] A new study created in RDB with name: ackley_bo_parafac_dim5_rank2_mask0.1_tradeoff3.0_seed0_includeobsFalse
2024-11-09 12:14:38,776 - INFO - Created new study 'ackley_bo_parafac_dim5_rank2_mask0.1_tradeoff3.0_seed0_includeobsFalse' in sqlite:////Users/keisukeonoue/ws/constrained_BO_v2/results/dbs/2024-11-09_12-14-38_ackley_bo_parafac_dim5_rank2_mask0.1_tradeoff3.0_seed0_includeobsFalse.db
2024-11-09 12:14:38,787 - INFO - Using sample_independent for sampling.
2024-11-09 12:14:38,790 - INFO - Using sample_independent for sampling.
2024-11-09 12:14:38,791 - INFO - Using sample_independent for sampling.
2024-11-09 12:14:38,792 - INFO - Using sample_independent for sampling.
2024-11-09 12:14:38,794 - INFO - Using sample_independent for sampling.
[I 2024-11-09 12:14:38,802] Trial 0 finished with value: 10.876298401763682 and parameters: {'x_0': -4, 'x_1': -4, 'x_2': -5, 'x_3': 2, 'x_4': -4}. Best is trial 0 with value: 10.876298401763682.


diff of min max ucb_values: 0.021957580725384673


2024-11-09 12:14:39,099 - INFO - Candidate Mean Stats: {'Max': np.float64(10.87438285541727), 'Min': np.float64(10.87438285541727), 'Mean': np.float64(10.87438285541727), 'Std': np.float64(0.
~
[I 2024-11-09 12:17:45,976] Trial 299 finished with value: 10.221456752498272 and parameters: {'x_0': 2, 'x_1': 3, 'x_2': 1, 'x_3': 5, 'x_4': -5}. Best is trial 65 with value: 2.8703147202665.
2024-11-09 12:17:45,977 - INFO - Best value: 2.8703147202665
2024-11-09 12:17:45,979 - INFO - Best params: {'x_0': 0, 'x_1': 0, 'x_2': -1, 'x_3': 1, 'x_4': 1}
(bo-env_v2) keisukeonoue@ws23is058 [12:17:46] [~/ws/constrained_BO_v2] [main *]
"""
