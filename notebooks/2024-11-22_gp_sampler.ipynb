# %%
import optuna
from optuna.samplers import GPSampler
import time  # 時間計測用


def objective(trial):
    # 最適化する関数（例: 二次関数）
    x = trial.suggest_float("x", -10.0, 10.0)  # 範囲を -10 から 10 に設定
    y = trial.suggest_float("y", -10.0, 10.0)  # 別の変数も探索
    return (x - 2) ** 2 + (y + 3) ** 2  # 最小化すべき目的関数


if __name__ == "__main__":
    n_trials = 2000

    # GPSampler を使用
    n_startup_trials = 1900
    sampler = GPSampler(n_startup_trials=n_startup_trials)
    
    # 時間計測開始
    start_time = time.time()
    
    # Optuna スタディの作成
    study = optuna.create_study(sampler=sampler, direction="minimize")
    
    # 最適化の実行
    study.optimize(objective, n_trials=n_trials)
    
    # 時間計測終了
    end_time = time.time()
    
    # 計測時間を表示
    elapsed_time = end_time - start_time
    print(f"最適化にかかった時間: {elapsed_time:.2f} 秒")
    
    # 結果の表示
    print(f"最良のパラメータ: {study.best_params}")
    print(f"最良の値: {study.best_value}")
# Out:
# /var/folders/_b/b62kq0490fn2ptq7m4mbp8yr0000gp/T/ipykernel_47144/231376354.py:18: ExperimentalWarning: GPSampler is experimental (supported from v3.6.0). The interface can change in the future.
#   sampler = GPSampler(n_startup_trials=n_startup_trials)
# [I 2024-11-22 11:36:47,210] A new study created in memory with name: no-name-866cfe04-2a7b-4de7-bf32-2d0d95f0a10b
# [I 2024-11-22 11:36:47,226] Trial 0 finished with value: 76.20235262444349 and parameters: {'x': -1.3944840102008849, 'y': 5.042377193898209}. Best is trial 0 with value: 76.20235262444349.
# [I 2024-11-22 11:36:47,226] Trial 1 finished with value: 78.00520731588259 and parameters: {'x': 6.014130598875809, 'y': 4.8671445169801935}. Best is trial 0 with value: 76.20235262444349.
# [I 2024-11-22 11:36:47,227] Trial 2 finished with value: 58.1179188719603 and parameters: {'x': 7.864387504929356, 'y': 1.8710243341610133}. Best is trial 2 with value: 58.1179188719603.
# [I 2024-11-22 11:36:47,227] Trial 3 finished with value: 46.78137442157953 and parameters: {'x': 6.505560678668334, 'y': -8.145998192034007}. Best is trial 3 with value: 46.78137442157953.
# [I 2024-11-22 11:36:47,228] Trial 4 finished with value: 70.64727730319301 and parameters: {'x': -6.0525278231263835, 'y': -5.40916436985285}. Best is trial 3 with value: 46.78137442157953.
# [I 2024-11-22 11:36:47,228] Trial 5 finished with value: 23.57923066352265 and parameters: {'x': 6.6880977300678595, 'y': -1.7347054347484003}. Best is trial 5 with value: 23.57923066352265.
# [I 2024-11-22 11:36:47,229] Trial 6 finished with value: 53.63243930308106 and parameters: {'x': 6.337491178594967, 'y': 2.9007295802037825}. Best is trial 5 with value: 23.57923066352265.
# [I 2024-11-22 11:36:47,230] Trial 7 finished with value: 140.92625165746267 and parameters: {'x': -4.572328279109534, 'y': 6.8858865383474726}. Best is trial 5 with value: 23.57923066352265.
# [I 2024-11-22 11:36:47,230] Trial 8 finished with value: 46.7984918114197 and parameters: {'x': 1.3013790325234798, 'y': 3.805176012067717}. Best is trial 5 with value: 23.57923066352265.
# [I 2024-11-22 11:36:47,230] Trial 9 finished with value: 16.737639232229746 and parameters: {'x': 5.9896816012699166, 'y': -3.9055826592410336}. Best is trial 9 with value: 16.737639232229746.
# [I 2024-11-22 11:36:47
. Best is trial 100 with value: 0.6793885739634208.
# [I 2024-11-22 11:36:47,474] Trial 233 finished with value: 3.531521033350824 and parameters: {'x': 2.482726688346595, 'y': -4.816176196768572}. Best is trial 100 with value: 0.6793885739634208.
# [I 2024-11-22 11:36:47,475] Trial 234 finished with value: 113.8733839709354 and parameters: {'x': -7.434963241542052, 'y': -7.985464131019868}. Best is trial 100 with value: 0.6793885739634208.
# [I 2024-11-22 11:36:47,475] Trial 235 finished with value: 65.89993377532724 and parameters: {'x': -3.5274803166305024, 'y': 2.9453254851681243}. Best is trial 100 with value: 0.6793885739634208.
# [I 2024-11-22 11:36:47,475] Trial 236 finished with value: 161.27284873272043 and parameters: {'x': -0.10048950254146982, 'y': 9.524407873525739}. Best is trial 100 with value: 0.6793885739634208.
# [I 2024-11-22 11:36:47,476] Trial 237 finished with value: 188.20886060269459 and parameters: {'x': 8.698754277851561, 'y': 8.972282644828429}. Best is trial 100 with value: 0.6793885739634208.
# [I 2024-11-22 11:36:47,476] Trial 238 finished with value: 173.59688416037437 and parameters: {'x': -9.484350768729964, 'y': -9.458062525335741}. Best is trial 100 with value: 0.6793885739634208.
# [I 2024-11-22 11:36:47,477] Trial 239 finished with value: 1.3228568826146274 and parameters: {'x': 1.8675123981557773, 'y': -4.1424989794184475}. Best is trial 100 with value: 0.6793885739634208.
# [I 2024-11-22 11:36:47,477] Trial 240 finished with value: 137.332505072757 and parameters: {'x': -2.5955029428848486, 'y': 7.780253140566491}. Best is trial 100 with value: 0.6793885739634208.
# [I 2024-11-22 11:36:47,477] Trial 241 finished with value: 34.17772227524696 and parameters: {'x': -0.19828508861963412, 'y': 2.4171270009479673}. Best is trial 100 with value: 0.6793885739634208.
# [I 2024-11-22 11:36:47,478] Trial 242 finished with value: 10.476750952357426 and parameters: {'x': 3.495265984847271, 'y': -5.870702106962014}. Best is trial 100 with value: 0.6793885739634208.
# [I 2024-11-22 11:36:47,479] Trial 243 finished with value: 168.7769736665254 and parameters: {'x': -9.749221536145917, 'y': 2.54371418465007}. Best is trial 100 with value: 0.6793885739634208.
# [I 2024-11-22 11:36:47,480] Trial 244 finished with value: 59.35927479490346 and parameters: {'x': -1.7579343788235358, 'y': 3.725860837049755}. Best is trial 100 with value: 0.6793885739634208.
# ...
#     fx = self._wrapped_fun(self.x)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/keisukeonoue/ws/constrained_BO_v3/bo-env_v3/lib/python3.12/site-packages/scipy/optimize/_differentiable_functions.py", line 20, in wrapped
#     fx = fun(np.copy(x), *args)
#          ^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/keisukeonoue/ws/constrained_BO_v3/bo-env_v3/lib/python3.12/site-packages/scipy/optimize/_optimize.py", line 79, in __call__
#     self._compute_if_needed(x, *args)
#   File "/Users/keisukeonoue/ws/constrained_BO_v3/bo-env_v3/lib/python3.12/site-packages/scipy/optimize/_optimize.py", line 73, in _compute_if_needed
#     fg = self.fun(x, *args)
#          ^^^^^^^^^^^^^^^^^^
#   File "/Users/keisukeonoue/ws/constrained_BO_v3/optuna/optuna/_gp/gp.py", line 190, in loss_func
#     loss.backward()  # type: ignore
#     ^^^^^^^^^^^^^^^
#   File "/Users/keisukeonoue/ws/constrained_BO_v3/bo-env_v3/lib/python3.12/site-packages/torch/_tensor.py", line 521, in backward
#     torch.autograd.backward(
#   File "/Users/keisukeonoue/ws/constrained_BO_v3/bo-env_v3/lib/python3.12/site-packages/torch/autograd/__init__.py", line 289, in backward
#     _engine_run_backward(
#   File "/Users/keisukeonoue/ws/constrained_BO_v3/bo-env_v3/lib/python3.12/site-packages/torch/autograd/graph.py", line 769, in _engine_run_backward
#     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/keisukeonoue/ws/constrained_BO_v3/bo-env_v3/lib/python3.12/site-packages/torch/autograd/function.py", line 291, in apply
#     def apply(self, *args):
#
# KeyboardInterrupt
# [W 2024-11-22 11:37:54,675] Trial 1906 failed with value None.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 27
#      24 study = optuna.create_study(sampler=sampler, direction="minimize")
#      26 # 最適化の実行
# ---> 27 study.optimize(objective, n_trials=n_trials)
#      29 # 時間計測終了
#      30 end_time = time.time()
#
# File ~/ws/constrained_BO_v3/optuna/optuna/study/study.py:475, in Study.optimize(self, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#     373 def optimize(
#     374     self,
#     375     func: ObjectiveFuncType,
#    (...)
#     382     show_progress_bar: bool = False,
#     383 ) -> None:
#     384     """Optimize an objective function.
#     385
#     386     Optimization is done by choosing a suitable set of hyperparameter values from a given
#    (...)
#     473             If nested invocation of this method occurs.
#     474     """
# --> 475     _optimize(
#     476         study=self,
#     477         func=func,
#     478         n_trials=n_trials,
#     479         timeout=timeout,
#     480         n_jobs=n_jobs,
#     481         catch=tuple(catch) if isinstance(catch, Iterable) else (catch,),
#     482         callbacks=callbacks,
#     483         gc_after_trial=gc_after_trial,
#     484         show_progress_bar=show_progress_bar,
#     485     )
#
# File ~/ws/constrained_BO_v3/optuna/optuna/study/_optimize.py:63, in _optimize(study, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#      61 try:
#      62     if n_jobs == 1:
# ---> 63         _optimize_sequential(
#      64             study,
#      65             func,
#      66             n_trials,
#      67             timeout,
#      68             catch,
#      69             callbacks,
#      70             gc_after_trial,
#      71             reseed_sampler_rng=False,
#      72             time_start=None,
#      73             progress_bar=progress_bar,
#      74         )
#      75     else:
#      76         if n_jobs == -1:
#
# File ~/ws/constrained_BO_v3/optuna/optuna/study/_optimize.py:160, in _optimize_sequential(study, func, n_trials, timeout, catch, callbacks, gc_after_trial, reseed_sampler_rng, time_start, progress_bar)
#     157         break
#     159 try:
# --> 160     frozen_trial = _run_trial(study, func, catch)
#     161 finally:
#     162     # The following line mitigates memory problems that can be occurred in some
#     163     # environments (e.g., services that use computing containers such as GitHub Actions).
#     164     # Please refer to the following PR for further details:
#     165     # https://github.com/optuna/optuna/pull/325.
#     166     if gc_after_trial:
#
# File ~/ws/constrained_BO_v3/optuna/optuna/study/_optimize.py:248, in _run_trial(study, func, catch)
#     241         assert False, "Should not reach."
#     243 if (
#     244     frozen_trial.state == TrialState.FAIL
#     245     and func_err is not None
#     246     and not isinstance(func_err, catch)
#     247 ):
# --> 248     raise func_err
#     249 return frozen_trial
#
# File ~/ws/constrained_BO_v3/optuna/optuna/study/_optimize.py:197, in _run_trial(study, func, catch)
#     195 with get_heartbeat_thread(trial._trial_id, study._storage):
#     196     try:
# --> 197         value_or_values = func(trial)
#     198     except exceptions.TrialPruned as e:
#     199         # TODO(mamu): Handle multi-objective cases.
#     200         state = TrialState.PRUNED
#
# Cell In[1], line 8, in objective(trial)
#       6 def objective(trial):
#       7     # 最適化する関数（例: 二次関数）
# ----> 8     x = trial.suggest_float("x", -10.0, 10.0)  # 範囲を -10 から 10 に設定
#       9     y = trial.suggest_float("y", -10.0, 10.0)  # 別の変数も探索
#      10     return (x - 2) ** 2 + (y + 3) ** 2
#
# File ~/ws/constrained_BO_v3/optuna/optuna/trial/_trial.py:161, in Trial.suggest_float(self, name, low, high, step, log)
#      85 """Suggest a value for the floating point parameter.
#      86
#      87 Example:
#    (...)
#     157     :ref:`configurations` tutorial describes more details and flexible usages.
#     158 """
#     160 distribution = FloatDistribution(low, high, log=log, step=step)
# --> 161 suggested_value = self._suggest(name, distribution)
#     162 self._check_distribution(name, distribution)
#     163 return suggested_value
#
# File ~/ws/constrained_BO_v3/optuna/optuna/trial/_trial.py:627, in Trial._suggest(self, name, distribution)
#     625 elif distribution.single():
#     626     param_value = distributions._get_single_value(distribution)
# --> 627 elif self._is_relative_param(name, distribution):
#     628     param_value = self.relative_params[name]
#     629 else:
#
# File ~/ws/constrained_BO_v3/optuna/optuna/trial/_trial.py:659, in Trial._is_relative_param(self, name, distribution)
#     658 def _is_relative_param(self, name: str, distribution: BaseDistribution) -> bool:
# --> 659     if name not in self.relative_params:
#     660         return False
#     662     if name not in self.relative_search_space:
#
# File ~/ws/constrained_BO_v3/optuna/optuna/trial/_trial.py:71, in Trial.relative_params(self)
#      69 if self._relative_params is None:
#      70     study = pruners._filter_study(self.study, self._cached_frozen_trial)
# ---> 71     self._relative_params = self.study.sampler.sample_relative(
#      72         study, self._cached_frozen_trial, self.relative_search_space
#      73     )
#      74 return self._relative_params
#
# File ~/ws/constrained_BO_v3/optuna/optuna/samplers/_gp/sampler.py:176, in GPSampler.sample_relative(self, study, trial, search_space)
#     170 if self._kernel_params_cache is not None and len(
#     171     self._kernel_params_cache.inverse_squared_lengthscales
#     172 ) != len(internal_search_space.scale_types):
#     173     # Clear cache if the search space changes.
#     174     self._kernel_params_cache = None
# --> 176 kernel_params = gp.fit_kernel_params(
#     177     X=normalized_params,
#     178     Y=standarized_score_vals,
#     179     is_categorical=(
#     180         internal_search_space.scale_types == gp_search_space.ScaleType.CATEGORICAL
#     181     ),
#     182     log_prior=self._log_prior,
#     183     minimum_noise=self._minimum_noise,
#     184     initial_kernel_params=self._kernel_params_cache,
#     185     deterministic_objective=self._deterministic,
#     186 )
#     187 self._kernel_params_cache = kernel_params
#     189 acqf_params = acqf.create_acqf_params(
#     190     acqf_type=acqf.AcquisitionFunctionType.LOG_EI,
#     191     kernel_params=kernel_params,
#    (...)
#     194     Y=standarized_score_vals,
#     195 )
#
# File ~/ws/constrained_BO_v3/optuna/optuna/_gp/gp.py:246, in fit_kernel_params(X, Y, is_categorical, log_prior, minimum_noise, deterministic_objective, initial_kernel_params, gtol)
#     244 for init_kernel_params in [initial_kernel_params, default_initial_kernel_params]:
#     245     try:
# --> 246         return _fit_kernel_params(
#     247             X=X,
#     248             Y=Y,
#     249             is_categorical=is_categorical,
#     250             log_prior=log_prior,
#     251             minimum_noise=minimum_noise,
#     252             initial_kernel_params=init_kernel_params,
#     253             deterministic_objective=deterministic_objective,
#     254             gtol=gtol,
#     255         )
#     256     except RuntimeError as e:
#     257         error = e
#
# File ~/ws/constrained_BO_v3/optuna/optuna/_gp/gp.py:197, in _fit_kernel_params(X, Y, is_categorical, log_prior, minimum_noise, deterministic_objective, initial_kernel_params, gtol)
#     194     return loss.item(), raw_params_tensor.grad.detach().numpy()  # type: ignore
#     196 # jac=True means loss_func returns the gradient for gradient descent.
# --> 197 res = so.minimize(
#     198     # Too small `gtol` causes instability in loss_func optimization.
#     199     loss_func,
#     200     initial_raw_params,
#     201     jac=True,
#     202     method="l-bfgs-b",
#     203     options={"gtol": gtol},
#     204 )
#     205 if not res.success:
#     206     raise RuntimeError(f"Optimization failed: {res.message}")
#
# File ~/ws/constrained_BO_v3/bo-env_v3/lib/python3.12/site-packages/scipy/optimize/_minimize.py:731, in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     728     res = _minimize_newtoncg(fun, x0, args, jac, hess, hessp, callback,
#     729                              **options)
#     730 elif meth == 'l-bfgs-b':
# --> 731     res = _minimize_lbfgsb(fun, x0, args, jac, bounds,
#     732                            callback=callback, **options)
#     733 elif meth == 'tnc':
#     734     res = _minimize_tnc(fun, x0, args, jac, bounds, callback=callback,
#     735                         **options)
#
# File ~/ws/constrained_BO_v3/bo-env_v3/lib/python3.12/site-packages/scipy/optimize/_lbfgsb_py.py:407, in _minimize_lbfgsb(fun, x0, args, jac, bounds, disp, maxcor, ftol, gtol, eps, maxfun, maxiter, iprint, callback, maxls, finite_diff_rel_step, **unknown_options)
#     401 task_str = task.tobytes()
#     402 if task_str.startswith(b'FG'):
#     403     # The minimization routine wants f and g at the current x.
#     404     # Note that interruptions due to maxfun are postponed
#     405     # until the completion of the current minimization iteration.
#     406     # Overwrite f and g:
# --> 407     f, g = func_and_grad(x)
#     408 elif task_str.startswith(b'NEW_X'):
#     409     # new iteration
#     410     n_iterations += 1
#
# File ~/ws/constrained_BO_v3/bo-env_v3/lib/python3.12/site-packages/scipy/optimize/_differentiable_functions.py:343, in ScalarFunction.fun_and_grad(self, x)
#     341 if not np.array_equal(x, self.x):
#     342     self._update_x(x)
# --> 343 self._update_fun()
#     344 self._update_grad()
#     345 return self.f, self.g
#
# File ~/ws/constrained_BO_v3/bo-env_v3/lib/python3.12/site-packages/scipy/optimize/_differentiable_functions.py:294, in ScalarFunction._update_fun(self)
#     292 def _update_fun(self):
#     293     if not self.f_updated:
# --> 294         fx = self._wrapped_fun(self.x)
#     295         if fx < self._lowest_f:
#     296             self._lowest_x = self.x
#
# File ~/ws/constrained_BO_v3/bo-env_v3/lib/python3.12/site-packages/scipy/optimize/_differentiable_functions.py:20, in _wrapper_fun.<locals>.wrapped(x)
#      16 ncalls[0] += 1
#      17 # Send a copy because the user may overwrite it.
#      18 # Overwriting results in undefined behaviour because
#      19 # fun(self.x) will change self.x, with the two no longer linked.
# ---> 20 fx = fun(np.copy(x), *args)
#      21 # Make sure the function returns a true scalar
#      22 if not np.isscalar(fx):
#
# File ~/ws/constrained_BO_v3/bo-env_v3/lib/python3.12/site-packages/scipy/optimize/_optimize.py:79, in MemoizeJac.__call__(self, x, *args)
#      77 def __call__(self, x, *args):
#      78     """ returns the function value """
# ---> 79     self._compute_if_needed(x, *args)
#      80     return self._value
#
# File ~/ws/constrained_BO_v3/bo-env_v3/lib/python3.12/site-packages/scipy/optimize/_optimize.py:73, in MemoizeJac._compute_if_needed(self, x, *args)
#      71 if not np.all(x == self.x) or self._value is None or self.jac is None:
#      72     self.x = np.asarray(x).copy()
# ---> 73     fg = self.fun(x, *args)
#      74     self.jac = fg[1]
#      75     self._value = fg[0]
#
# File ~/ws/constrained_BO_v3/optuna/optuna/_gp/gp.py:190, in _fit_kernel_params.<locals>.loss_func(raw_params)
#     178 params = KernelParamsTensor(
#     179     inverse_squared_lengthscales=torch.exp(raw_params_tensor[:n_params]),
#     180     kernel_scale=torch.exp(raw_params_tensor[n_params]),
#    (...)
#     185     ),
#     186 )
#     187 loss = -marginal_log_likelihood(
#     188     torch.from_numpy(X), torch.from_numpy(Y), torch.from_numpy(is_categorical), params
#     189 ) - log_prior(params)
# --> 190 loss.backward()  # type: ignore
#     191 # scipy.minimize requires all the gradients to be zero for termination.
#     192 raw_noise_var_grad = raw_params_tensor.grad[n_params + 1]  # type: ignore
#
# File ~/ws/constrained_BO_v3/bo-env_v3/lib/python3.12/site-packages/torch/_tensor.py:521, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     511 if has_torch_function_unary(self):
#     512     return handle_torch_function(
#     513         Tensor.backward,
#     514         (self,),
#    (...)
#     519         inputs=inputs,
#     520     )
# --> 521 torch.autograd.backward(
#     522     self, gradient, retain_graph, create_graph, inputs=inputs
#     523 )
#
# File ~/ws/constrained_BO_v3/bo-env_v3/lib/python3.12/site-packages/torch/autograd/__init__.py:289, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     284     retain_graph = create_graph
#     286 # The reason we repeat the same comment below is that
#     287 # some Python versions print out the first line of a multi-line function
#     288 # calls in the traceback and some print out the last line
# --> 289 _engine_run_backward(
#     290     tensors,
#     291     grad_tensors_,
#     292     retain_graph,
#     293     create_graph,
#     294     inputs,
#     295     allow_unreachable=True,
#     296     accumulate_grad=True,
#     297 )
#
# File ~/ws/constrained_BO_v3/bo-env_v3/lib/python3.12/site-packages/torch/autograd/graph.py:769, in _engine_run_backward(t_outputs, *args, **kwargs)
#     767     unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     768 try:
# --> 769     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     770         t_outputs, *args, **kwargs
#     771     )  # Calls into the C++ engine to run the backward pass
#     772 finally:
#     773     if attach_logging_hooks:
#
# File ~/ws/constrained_BO_v3/bo-env_v3/lib/python3.12/site-packages/torch/autograd/function.py:291, in BackwardCFunction.apply(self, *args)
#     286 class BackwardCFunction(_C._FunctionBase, FunctionCtx, _HookMixin):
#     287     r"""
#     288     This class is used for internal autograd work. Do not use.
#     289     """
# --> 291     def apply(self, *args):
#     292         r"""
#     293         Apply method used when executing this Node during the backward
#     294         """
#     295         # _forward_cls is defined by derived class
#     296         # The user should define either backward or vjp but never both.
#
# KeyboardInterrupt:
